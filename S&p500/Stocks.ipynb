# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period = "max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1950-01-03 00:00:00-05:00    16.660000    16.660000    16.660000    16.660000
# 1950-01-04 00:00:00-05:00    16.850000    16.850000    16.850000    16.850000
# 1950-01-05 00:00:00-05:00    16.930000    16.930000    16.930000    16.930000
# 1950-01-06 00:00:00-05:00    16.980000    16.980000    16.980000    16.980000
# 1950-01-09 00:00:00-05:00    17.080000    17.080000    17.080000    17.080000
# ...                                ...          ...          ...          ...
# 2022-10-14 00:00:00-04:00  3690.409912  3712.000000  3579.679932  3583.070068
# 2022-10-17 00:00:00-04:00  3638.649902  3689.729980  3638.649902  3677.949951
# 2022-10-18 00:00:00-04:00  3746.260010  3762.790039  3686.530029  3719.979980
# 2022-10-19 00:00:00-04:00  3703.110107  3728.580078  3666.510010  3695.159912
# 2022-10-20 00:00:00-04:00  3689.050049  3736.000000  3656.439941  3665.780029
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1950-01-03 00:00:00-05:00', '1950-01-04 00:00:00-05:00',
#                '1950-01-05 00:00:00-05:00', '1950-01-06 00:00:00-05:00',
#                '1950-01-09 00:00:00-05:00', '1950-01-10 00:00:00-05:00',
#                '1950-01-11 00:00:00-05:00', '1950-01-12 00:00:00-05:00',
#                '1950-01-13 00:00:00-05:00', '1950-01-16 00:00:00-05:00',
#                ...
#                '2022-10-07 00:00:00-04:00', '2022-10-10 00:00:00-04:00',
#                '2022-10-11 00:00:00-04:00', '2022-10-12 00:00:00-04:00',
#                '2022-10-13 00:00:00-04:00', '2022-10-14 00:00:00-04:00',
#                '2022-10-17 00:00:00-04:00', '2022-10-18 00:00:00-04:00',
#                '2022-10-19 00:00:00-04:00', '2022-10-20 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=18320, freq=None)

# %%
sp500.plot.line(y = "Close", use_index = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)
#create a new column with tomorrows prices also for each day

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1950-01-03 00:00:00-05:00    16.660000    16.660000    16.660000    16.660000
# 1950-01-04 00:00:00-05:00    16.850000    16.850000    16.850000    16.850000
# 1950-01-05 00:00:00-05:00    16.930000    16.930000    16.930000    16.930000
# 1950-01-06 00:00:00-05:00    16.980000    16.980000    16.980000    16.980000
# 1950-01-09 00:00:00-05:00    17.080000    17.080000    17.080000    17.080000
# ...                                ...          ...          ...          ...
# 2022-10-14 00:00:00-04:00  3690.409912  3712.000000  3579.679932  3583.070068
# 2022-10-17 00:00:00-04:00  3638.649902  3689.729980  3638.649902  3677.949951
# 2022-10-18 00:00:00-04:00  3746.260010  3762.790039  3686.530029  3719.979980
# 2022-10-19 00:00:00-04:00  3703.110107  3728.580078  3666.510010  3695.159912
# 2022-10-20 00:00:00-04:00  3689.050049  3736.000000  3656.439941  3665.780029
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
#is tomorrows price greater than today's price
#we are trying to predict if tomorrow's price is greather than today's price

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1950-01-03 00:00:00-05:00    16.660000    16.660000    16.660000    16.660000
# 1950-01-04 00:00:00-05:00    16.850000    16.850000    16.850000    16.850000
# 1950-01-05 00:00:00-05:00    16.930000    16.930000    16.930000    16.930000
# 1950-01-06 00:00:00-05:00    16.980000    16.980000    16.980000    16.980000
# 1950-01-09 00:00:00-05:00    17.080000    17.080000    17.080000    17.080000
# ...                                ...          ...          ...          ...
# 2022-10-14 00:00:00-04:00  3690.409912  3712.000000  3579.679932  3583.070068
# 2022-10-17 00:00:00-04:00  3638.649902  3689.729980  3638.649902  3677.949951
# 2022-10-18 00:00:00-04:00  3746.260010  3762.790039  3686.530029  3719.979980
# 2022-10-19 00:00:00-04:00  3703.110107  3728.580078  3666.510010  3695.159912
# 2022-10-20 00:00:00-04:00  3689.050049  3736.000000  3656.439941  3665.780029
#
# ...

# %%
#too far behind
sp500 = sp500.loc["1990-01-01":].copy()
#dates after Jan 1st 1990

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2022-10-14 00:00:00-04:00  3690.409912  3712.000000  3579.679932  3583.070068
# 2022-10-17 00:00:00-04:00  3638.649902  3689.729980  3638.649902  3677.949951
# 2022-10-18 00:00:00-04:00  3746.260010  3762.790039  3686.530029  3719.979980
# 2022-10-19 00:00:00-04:00  3703.110107  3728.580078  3666.510010  3695.159912
# 2022-10-20 00:00:00-04:00  3689.050049  3736.000000  3656.439941  3665.780029
#
# ...

# %%
#we have our model

#training a bunch of invididual decision trees with random parameters
#averaging those results
#hard to overfit
#alaso run quickly
#can pick up non-linear trends ex open price and close price are random
#

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, min_samples_split=100, random_state=1)
#random-state use same values so get same model
#min_samples_list = less means less overfitting
#n_estimators = number of individual trees, more = accuracy

train = sp500.iloc[:-100] #real life bc we don't know what is happening in real life
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
#measure accuracy of model

from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index = test.index)

# %%
preds
# Out:
# Date
# 2022-05-31 00:00:00-04:00    1
# 2022-06-01 00:00:00-04:00    1
# 2022-06-02 00:00:00-04:00    0
# 2022-06-03 00:00:00-04:00    1
# 2022-06-06 00:00:00-04:00    1
#                             ..
# 2022-10-14 00:00:00-04:00    1
# 2022-10-17 00:00:00-04:00    1
# 2022-10-18 00:00:00-04:00    1
# 2022-10-19 00:00:00-04:00    1
# 2022-10-20 00:00:00-04:00    1
# Length: 100, dtype: int64

# %%
precision_score(test["Target"], preds) #not a good prediction score
# Out:
# 0.4125

# %%
combined = pd.concat([test["Target"], preds], axis = 1)
combined
# Out:
#                            Target  0
# Date
# 2022-05-31 00:00:00-04:00       0  1
# 2022-06-01 00:00:00-04:00       1  1
# 2022-06-02 00:00:00-04:00       0  0
# 2022-06-03 00:00:00-04:00       1  1
# 2022-06-06 00:00:00-04:00       1  1
# ...                           ... ..
# 2022-10-14 00:00:00-04:00       1  1
# 2022-10-17 00:00:00-04:00       1  1
# 2022-10-18 00:00:00-04:00       0  1
# 2022-10-19 00:00:00-04:00       0  1
# 2022-10-20 00:00:00-04:00       0  1
#
# [100 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#BACKTESTING

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
#0 - market down on 3342 days
#1  - up on 2422 days
# Out:
# 0    3341
# 1    2425
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5319587628865979

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.53486
# 0    0.46514
# Name: Target, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2022-10-14 00:00:00-04:00  3690.409912  3712.000000  3579.679932  3583.070068
# 2022-10-17 00:00:00-04:00  3638.649902  3689.729980  3638.649902  3677.949951
# 2022-10-18 00:00:00-04:00  3746.260010  3762.790039  3686.530029  3719.979980
# 2022-10-19 00:00:00-04:00  3703.110107  3728.580078  3666.510010  3695.159912
# 2022-10-20 00:00:00-04:00  3689.050049  3736.000000  3656.439941  3665.780029
#
# ...

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    3954
# 1.0     812
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5689655172413793

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.545321
# 0    0.454679
# Name: Target, dtype: float64

# %%
predictions
